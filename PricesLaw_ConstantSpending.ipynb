# %% [markdown]
# <a href="https://colab.research.google.com/github/morekaccino/PricesLaw/blob/main/PricesLaw_ConstantSpending.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With Constant Spending

# %%
from enum import Enum
from random import randint, choice
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 100
pop = np.ones((n, n), dtype=np.int)
class Direction(Enum):
  top = 0
  bottom = 1
  left = 2
  right = 3

# %%
def epoch():
  for i in range(len(pop)):
    for j in range(len(pop[i])):
      
      if pop[i, j] == 0:
        continue
      
      direction = choice(list(Direction))
      if direction == Direction.top:
        pop[(i-1) % n, j] += 1
      elif direction == Direction.bottom:
        pop[(i+1) % n, j] += 1
      elif direction == Direction.left:
        pop[i, (j-1) % n] += 1
      elif direction == Direction.right:
        pop[i, (j+1) % n] += 1
      else:
        raise Exception("None of the direction were matched.")
      pop[i, j] -= 1

# %%
for q in range(1000):
  epoch()

# %%
plt.figure(figsize=(20, 20))
plt.title('Actual Function')
heatmap = plt.pcolor(pop, cmap='RdBu')
plt.show()

# %%
linear = np.copy(pop)
linear = linear.reshape(n*n)
linear = np.sort(linear)

plt.figure(figsize=(20, 20))
plt.fill_between(list(range(1, 10001)), linear, color='orange', alpha=0.5)
plt.plot(list(range(1, 10001)), linear, color='orange')

# %% [markdown]
# Lower 50 percent wealth possession: 352<br>
# Top 1 percent wealth pessession: 764<br>
# $ratio = \frac{top \, 1 \, percent}{lower \, 50 \, percent} = \frac{764}{352}=2.17$

# %%
# lower 50 percent
lower = sum(linear[0:n*n//2])
top1 =  sum(linear[(n*n)-((n*n)//100):])

print('lower 50%:',lower)
print('top one percent:',top1)
# Out:
# lower 50%: 352
# top one percent: 764
